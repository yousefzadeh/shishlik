# %% [markdown]
# # Move unreferenced models to archived folder

# %%
import json 
import pandas as pd
import os 
import numpy as np

# %%
os.chdir("..")
os.getcwd()
# Out:
# '/home/herman/projects/6clicksReporting'

# %%
print("Starting Directory: "+os.getcwd())
os.chdir(os.getcwd() + "/target")
# Out:
# Starting Directory: /home/herman/projects/6clicksReporting

# %% [markdown]
# ## Build object dataframe from manifest.json
#
# ### 1. Load manifest.json
#
# Top level keys
#
# * metadata
# * nodes
# * sources
# * macros
# * docs
# * exposures
# * metrics
# * selectors
# * disabled
# * parent_map
# * child_map

# %%
with open('./manifest.json', 'r') as f:
    data = json.load(f)

# %% [markdown]
# ### 2. Union all the objects

# %% [markdown]
# ### 1. nodes
# Example json fragment of one entry
# ```
# "model.sixclicks_dev_orig.vwWorkflowStage": {
# 			"compiled": true,
# 			"resource_type": "model",
# 			"depends_on": {
# 				"macros": [
# 					"macro.sixclicks_dev_orig.system_remove_IsDeleted",
# 					"macro.sixclicks_dev_orig.col_rename"
# 				],
# 				"nodes": [
# 					"source.sixclicks_dev_orig.workflow_models.WorkflowStage"
# 				]
# 			},
# 			"config": {
# 				"enabled": true,
# 				"alias": null,
# 				"schema": null,
# 				"database": null,
# 				"tags": [],
# 				"meta": {},
# 				"materialized": "view",
# 				"incremental_strategy": null,
# 				"persist_docs": {},
# 				"quoting": {},
# 				"column_types": {},
# 				"full_refresh": null,
# 				"unique_key": null,
# 				"on_schema_change": "ignore",
# 				"grants": {},
# 				"packages": [],
# 				"docs": {
# 					"show": true,
# 					"node_color": null
# 				},
# 				"post-hook": [],
# 				"pre-hook": []
# 			},
# 			"database": "6clicks-dev-ihsopk",
# 			"schema": "test_dbt_cicd",
# 			"fqn": [
# 				"sixclicks_dev_orig",
# 				"Workflow",
# 				"vwWorkflowStage"
# 			],
# 			"unique_id": "model.sixclicks_dev_orig.vwWorkflowStage",
# 			"raw_code": "select * from somewhere",
# 			"language": "sql",
# 			"package_name": "sixclicks_dev_orig",
# 			"root_path": "/home/herman/projects/6clicksReporting",
# 			"path": "Workflow/vwWorkflowStage.sql",
# 			"original_file_path": "models/Workflow/vwWorkflowStage.sql",
# 			"name": "vwWorkflowStage",
# 			"alias": "vwWorkflowStage",
# 			"checksum": {
# 				"name": "sha256",
# 				"checksum": "d44cd9fe65237ad53bb652e8fea8b0cde9091beca6b89ad9d8b89730173f52ff"
# 			},
# 			"tags": [],
# 			"refs": [],
# 			"sources": [
# 				[
# 					"workflow_models",
# 					"WorkflowStage"
# 				]
# 			],
# 			"metrics": [],
# 			"description": "",
# 			"columns": {},
# 			"meta": {},
# 			"docs": {
# 				"show": true,
# 				"node_color": null
# 			},
# 			"patch_path": null,
# 			"compiled_path": "target/compiled/sixclicks_dev_orig/models/Workflow/vwWorkflowStage.sql",
# 			"build_path": "target/run/sixclicks_dev_orig/models/Workflow/vwWorkflowStage.sql",
# 			"deferred": false,
# 			"unrendered_config": {},
# 			"created_at": 1682394408.451133,
# 			"compiled_code": "select * from somewhere",
# 			"extra_ctes_injected": true,
# 			"extra_ctes": [],
# 			"relation_name": "\"6clicks-dev-ihsopk\".\"test_dbt_cicd\".\"vwWorkflowStage\""
# 		}
# ```

# %%
nodes_obj = pd.DataFrame({ 
    "id": [ n for n in data["nodes"].keys() ],
    "depends_on" : [ n["depends_on"] for n in data["nodes"].values() ],
    "materialized" : [ n["config"]["materialized"] for n in data["nodes"].values() ],
    "original_file_path" : [ n["original_file_path"] for n in data["nodes"].values() ],
    "name" : [ n["name"] for n in data["nodes"].values() ] 
    })
# nodes_obj

# %% [markdown]
# ### 2. sources
# Example fragment
# ```
# 		"source.sixclicks_dev_orig.workflow_models.Workflow": {
# 			"fqn": [
# 				"sixclicks_dev_orig",
# 				"Workflow",
# 				"workflow_models",
# 				"Workflow"
# 			],
# 			"database": "6clicks-dev-ihsopk",
# 			"schema": "dbo",
# 			"unique_id": "source.sixclicks_dev_orig.workflow_models.Workflow",
# 			"package_name": "sixclicks_dev_orig",
# 			"root_path": "/home/herman/projects/6clicksReporting",
# 			"path": "models/Workflow/workflow_models_reference_file.yml",
# 			"original_file_path": "models/Workflow/workflow_models_reference_file.yml",
# 			"name": "Workflow",
# 			"source_name": "workflow_models",
# 			"source_description": "",
# 			"loader": "",
# 			"identifier": "Workflow",
# 			"resource_type": "source",
# 			"quoting": {
# 				"database": null,
# 				"schema": null,
# 				"identifier": null,
# 				"column": null
# 			},
# 			"loaded_at_field": null,
# 			"freshness": {
# 				"warn_after": {
# 					"count": null,
# 					"period": null
# 				},
# 				"error_after": {
# 					"count": null,
# 					"period": null
# 				},
# 				"filter": null
# 			},
# 			"external": null,
# 			"description": "",
# 			"columns": {},
# 			"meta": {},
# 			"source_meta": {},
# 			"tags": [],
# 			"config": {
# 				"enabled": true
# 			},
# 			"patch_path": null,
# 			"unrendered_config": {},
# 			"relation_name": "\"6clicks-dev-ihsopk\".\"dbo\".\"Workflow\"",
# 			"created_at": 1682394414.8137027
# 		}
# ```

# %%
sources_obj = pd.DataFrame({ 
    "id": [ n for n in data["sources"].keys() ],
    "depends_on"   : [""] * len(data["sources"].keys()),
    "materialized" : ["table"] * len(data["sources"].keys()),
    "original_file_path" : [ n["original_file_path"] for n in data["sources"].values() ],
    "name" : [ n["name"] for n in data["sources"].values() ] 
    })
# sources_obj

# %% [markdown]
# ### 3. macros
# Example json fragment
# ```
# 		"macro.sixclicks_dev_orig.test_incremental": {
# 			"unique_id": "macro.sixclicks_dev_orig.test_incremental",
# 			"package_name": "sixclicks_dev_orig",
# 			"root_path": "/home/herman/projects/6clicksReporting",
# 			"path": "macros/test_incremental_table.sql",
# 			"original_file_path": "macros/test_incremental_table.sql",
# 			"name": "test_incremental",
# 			"macro_sql": "{% macro blablabla() %}",
# 			"resource_type": "macro",
# 			"tags": [],
# 			"depends_on": {
# 				"macros": []
# 			},
# 			"description": "",
# 			"meta": {},
# 			"docs": {
# 				"show": true,
# 				"node_color": null
# 			},
# 			"patch_path": null,
# 			"arguments": [],
# 			"created_at": 1682394407.2099958,
# 			"supported_languages": null
# 		}
# ```

# %%
macros_obj = pd.DataFrame({ 
    "id": [ n for n in data["macros"].keys() ],
    "depends_on" : [ n["depends_on"] for n in data["macros"].values() ],
    "materialized" : ["macros"] * len(data["macros"].keys()),
    "original_file_path" : [ n["original_file_path"] for n in data["macros"].values() ],
    "name" : [ n["name"] for n in data["macros"].values() ] 
    })
# macros_obj

# %% [markdown]
# ### 4. docs
# Example json fragment
# ```
# 		"dbt.__overview__": {
# 			"unique_id": "dbt.__overview__",
# 			"package_name": "dbt",
# 			"root_path": "/home/herman/.pyenv/versions/3.8/envs/dbt38/lib/python3.8/site-packages/dbt/include/global_project",
# 			"path": "overview.md",
# 			"original_file_path": "docs/overview.md",
# 			"name": "__overview__",
# 			"block_contents": "### Welcome!"
# 		}
# 	}
# ```

# %%
docs_obj = pd.DataFrame({ 
    "id": [ n for n in data["docs"].keys() ],
    "depends_on" : [""] * len(data["docs"].keys()),
    "materialized" : [""] * len(data["docs"].keys()),
    "original_file_path" : [ n["original_file_path"] for n in data["docs"].values() ],
    "name" : [ n["name"] for n in data["docs"].values() ] 
    })
# docs_obj

# %% [markdown]
# ### 5. exposures
# Example json fragment
# ```
# 		"exposure.sixclicks_dev_orig.Attestations": {
# 			"fqn": [
# 				"sixclicks_dev_orig",
# 				"YellowfinReport_views",
# 				"exposures",
# 				"Attestations"
# 			],
# 			"unique_id": "exposure.sixclicks_dev_orig.Attestations",
# 			"package_name": "sixclicks_dev_orig",
# 			"root_path": "/home/herman/projects/6clicksReporting",
# 			"path": "YellowfinReport_views/exposures/spinup_production_202304181230.yml",
# 			"original_file_path": "models/YellowfinReport_views/exposures/spinup_production_202304181230.yml",
# 			"name": "Attestations",
# 			"type": "dashboard",
# 			"owner": {
# 				"email": "ban.pradhan@minerra.net",
# 				"name": "Ban Pradhan parent"
# 			},
# 			"resource_type": "exposure",
# 			"description": "* View Name: Attestations\n* Description: New View\n* View ID: 270882\n* Folder: 6CLICKSREPORTSDASHBOARDS / ATTESTATIONS\n* Created By: Ban Pradhan parent / ban.pradhan@minerra.net on 2022-02-21\n* Modified By: Ban Pradhan parent / ban.pradhan@minerra.net on 2022-06-29\n",
# 			"label": null,
# 			"maturity": "medium",
# 			"meta": {},
# 			"tags": [],
# 			"config": {
# 				"enabled": true
# 			},
# 			"unrendered_config": {},
# 			"url": "https://yellowfin-dev-ihsopk.6clicks.io/logoff.i4",
# 			"depends_on": {
# 				"macros": [],
# 				"nodes": [
# 					"model.sixclicks_dev_orig.vwAbpUser",
# 					"model.sixclicks_dev_orig.vwAbpUser",
# 					"model.sixclicks_dev_orig.vwAttestationAttestors",
# 					"model.sixclicks_dev_orig.vwAttestationItems",
# 					"model.sixclicks_dev_orig.vwAttestationOwners",
# 					"model.sixclicks_dev_orig.vwAttestations",
# 					"model.sixclicks_dev_orig.vwAttestorApprovals"
# 				]
# 			},
# 			"refs": [
# 				[
# 					"vwAbpUser"
# 				],
# 				[
# 					"vwAbpUser"
# 				],
# 				[
# 					"vwAttestationAttestors"
# 				],
# 				[
# 					"vwAttestationItems"
# 				],
# 				[
# 					"vwAttestationOwners"
# 				],
# 				[
# 					"vwAttestations"
# 				],
# 				[
# 					"vwAttestorApprovals"
# 				]
# 			],
# 			"sources": [],
# 			"created_at": 1682394414.4026499
# 		}
# ```

# %%
exposures_obj = pd.DataFrame({ 
    "id": [ n for n in data["exposures"].keys() ],
    "depends_on" : [ n["depends_on"] for n in data["exposures"].values() ],
    "materialized" : ["exposure"] * len(data["exposures"].keys()),
    "original_file_path" : [ n["original_file_path"] for n in data["exposures"].values() ],
    "name" : [ n["name"] for n in data["exposures"].values() ] 
    })
# exposures_obj

# %% [markdown]
# ### 6. Union all into obj_df

# %%
obj_df = pd.concat([nodes_obj, sources_obj, macros_obj, docs_obj, exposures_obj], ignore_index=True)
#obj_df

# %% [markdown]
# ## 2. Build the Tree

# %% [markdown]
# ### 1. Table of nodes

# %%
nodes_df = pd.DataFrame({ 
    "parent": [ n for n in data["parent_map"].keys() ],
    "child" : [ n for n in data["parent_map"].values() ] 
    })

# %% [markdown]
# ### 2. Unnest the child column to get one row for each parent and child

# %%
nodes_unnest_df= nodes_df.explode("child", ignore_index=True)

# %% [markdown]
# ### 3. Filter only exposure and models as parent and models as children

# %%
selected_nodes_unnest_df = nodes_unnest_df.\
    query("parent.str.contains('^model|exposure.*',regex=True)").\
    query("child == child").\
    query("child.str.contains('^model|source.*',regex=True)")

# %% [markdown]
# ### 4. List of Root is the unique list of Exposures

# %%
root_list = list(set(selected_nodes_unnest_df.\
    query('parent.str.contains("^exposure.*")')["parent"].\
    tolist()))

# %% [markdown]
# ### 5. Build root_df from root_list

# %%
root_df = pd.DataFrame({ 
    "parent" : ["ROOT"] * len(root_list),
    "child" : root_list 
    })
# root_df

# %% [markdown]
# ### 6. Tree is union of the root and the rest of the tree

# %%
tree_df = pd.concat([selected_nodes_unnest_df,root_df], ignore_index=True)

# %%
tree_df
# Out:
#                                                  parent  \
# 0                  model.sixclicks_dev_orig.vwSignature
# 1     model.sixclicks_dev_orig.vwCosmosDbBackgroundJ...
# 2     model.sixclicks_dev_orig.vwVulnerabilitySeveri...
# 3     model.sixclicks_dev_orig.vwVulnerabilityImport...
# 4              model.sixclicks_dev_orig.vwVulnerability
# ...                                                 ...
# 2072                                               ROOT
# 2073                                               ROOT
# 2074                                               ROOT
# 2075                                               ROOT
# 2076                                               ROOT
#
#                                                   child
# 0     source.sixclicks_dev_orig.signature_models.Sig...
# 1     source.sixclicks_dev_orig.CosmosDbBackgroundJo...
# 2     source.sixclicks_dev_orig.vulnerability_models...
# 3     source.sixclicks_dev_orig.vulnerability_models...
# 4     source.sixclicks_dev_orig.vulnerability_models...
# ...                                                 ...
# 2072  exposure.sixclicks_dev_orig.Risks_and_Risk_Ass...
# 2073  exposure.sixclicks_dev_orig.Question_Based_Ass...
# 2074  exposure.sixclicks_dev_orig.Requirements_Based...
# 2075  exposure.sixclicks_dev_orig.Risk_Details_Advan...
# 2076  exposure.sixclicks_dev_orig.Custom_Register_Se...
#
# [2077 rows x 2 columns]

# %% [markdown]
# ## 3.
# ### 1. Mark parent column type in parent_group column
#
# Types
# 1. root
# 2. middle
# 3. base_view (model has only one child which is a source)

# %%
# base_view (model has only one child which is a source) 
tree_df["parent_group"] = np.where((tree_df["parent"].str.contains("^model.*") & tree_df["child"].str.contains("^source.*")),"base_view" ,"")
# root
tree_df["parent_group"] = np.where((tree_df["parent"].str.contains("^ROOT")),"root" ,tree_df["parent_group"])
# middle
tree_df["parent_group"] = np.where((tree_df["parent_group"] == ""),"middle" ,tree_df["parent_group"])

tree_df
# Out:
#                                                  parent  \
# 0                  model.sixclicks_dev_orig.vwSignature
# 1     model.sixclicks_dev_orig.vwCosmosDbBackgroundJ...
# 2     model.sixclicks_dev_orig.vwVulnerabilitySeveri...
# 3     model.sixclicks_dev_orig.vwVulnerabilityImport...
# 4              model.sixclicks_dev_orig.vwVulnerability
# ...                                                 ...
# 2072                                               ROOT
# 2073                                               ROOT
# 2074                                               ROOT
# 2075                                               ROOT
# 2076                                               ROOT
#
#                                                   child parent_group
# 0     source.sixclicks_dev_orig.signature_models.Sig...    base_view
# 1     source.sixclicks_dev_orig.CosmosDbBackgroundJo...    base_view
# 2     source.sixclicks_dev_orig.vulnerability_models...    base_view
# 3     source.sixclicks_dev_orig.vulnerability_models...    base_view
# 4     source.sixclicks_dev_orig.vulnerability_models...    base_view
# ...                                                 ...          ...
# 2072  exposure.sixclicks_dev_orig.Risks_and_Risk_Ass...         root
# 2073  exposure.sixclicks_dev_orig.Question_Based_Ass...         root
# 2074  exposure.sixclicks_dev_orig.Requirements_Based...         root
# 2075  exposure.sixclicks_dev_orig.Risk_Details_Advan...         root
# 2076  exposure.sixclicks_dev_orig.Custom_Register_Se...         root
#
# [2077 rows x 3 columns]

# %% [markdown]
# ### 2. Traverse the tree and do stuff

# %% [markdown]
# Traverse tree and mark the obj_df and tree_df

# %%
obj_df["notes"] = ""       # mark * if traverse tree visits the node
obj_df["pass_count"] = 0   # counts how many visits were made by traverse (How many references were made)
obj_df
# Out:
#                                                      id  \
# 0                  model.sixclicks_dev_orig.vwSignature
# 1     model.sixclicks_dev_orig.vwCosmosDbBackgroundJ...
# 2     model.sixclicks_dev_orig.vwVulnerabilitySeveri...
# 3     model.sixclicks_dev_orig.vwVulnerabilityImport...
# 4              model.sixclicks_dev_orig.vwVulnerability
# ...                                                 ...
# 1590          exposure.sixclicks_dev_orig.Vulnerability
# 1591   exposure.sixclicks_dev_orig.Risks_Matrix_Details
# 1592  exposure.sixclicks_dev_orig.Risk_Details_Advan...
# 1593  exposure.sixclicks_dev_orig.Risk_Details_Self-...
# 1594  exposure.sixclicks_dev_orig.Question_Based_Ass...
#
#                                              depends_on materialized  \
# 0     {'macros': ['macro.sixclicks_dev_orig.system_f...         view
# 1     {'macros': ['macro.sixclicks_dev_orig.col_rena...         view
# 2     {'macros': ['macro.sixclicks_dev_orig.system_r...         view
# 3     {'macros': ['macro.sixclicks_dev_orig.system_r...         view
# 4     {'macros': ['macro.sixclicks_dev_orig.system_r...         view
# ...                                                 ...          ...
# 1590  {'macros': [], 'nodes': ['model.sixclicks_dev_...     exposure
# 1591  {'macros': [], 'nodes': ['model.sixclicks_dev_...     exposure
# 1592  {'macros': [], 'nodes': ['model.sixclicks_dev_...     exposure
# 1593  {'macros': [], 'nodes': ['model.sixclicks_dev_...     exposure
# 1594  {'macros': [], 'nodes': ['model.sixclicks_dev_...     exposure
#
#                                      original_file_path  \
# 0          models/Signature_models/Base/vwSignature.sql
# 1     models/CosmosDbBackgroundJobLog_models/Base/vw...
# 2     models/Vulnerability/Base/vwVulnerabilitySever...
# 3     models/Vulnerability/Base/vwVulnerabilityImpor...
# 4         models/Vulnerability/Base/vwVulnerability.sql
# ...                                                 ...
# 1590  models/YellowfinReport_views/exposures/spinup_...
# 1591  models/YellowfinReport_views/exposures/spinup_...
# 1592  models/YellowfinReport_views/exposures/spinup_...
# 1593  models/YellowfinReport_views/exposures/spinup_...
# 1594  models/YellowfinReport_views/exposures/spinup_...
#
#                                                    name notes  pass_count
# 0                                           vwSignature                 0
# 1                            vwCosmosDbBackgroundJobLog                 0
# 2                   vwVulnerabilitySeverityFieldMapping                 0
# 3                          vwVulnerabilityImportFileLog                 0
# 4                                       vwVulnerability                 0
# ...                                                 ...   ...         ...
# 1590                                      Vulnerability                 0
# 1591                               Risks_Matrix_Details                 0
# 1592            Risk_Details_Advanced_Self-Service_View                 0
# 1593                     Risk_Details_Self-Service_View                 0
# 1594  Question_Based_Assessment_Question_Assigned_Us...                 0
#
# [1595 rows x 7 columns]

# %%
tree_df["pass_count"] = 0

# %% [markdown]
# Define functions

# %%
def mark_obj(id,note):
    global obj_df

    obj_df.loc[obj_df["id"] == id, "notes"] = note
    obj_df.loc[obj_df["id"] == id, "pass_count"] += 1
    tree_df.loc[tree_df["parent"] == id, "pass_count"] += 1

# %%
def traverse(node:str, level=0, silent=False):
    if not silent:
        print("\t"*level,node)
    mark_obj(node,"*")
    children_df = tree_df[tree_df["parent"].apply(lambda x: x == node)]
    if len(children_df["child"].tolist()) > 0:
        for child_node in children_df["child"]:
            traverse(child_node, level+1)  
    else:
        if not silent:
            print("-------------")

# %% [markdown]
# Traverse the tree

# %%
traverse("ROOT", silent = True) # set to False to see the path thru the tree for debugging
# Out:
# 	 exposure.sixclicks_dev_orig.Attestations
# 		 model.sixclicks_dev_orig.vwAbpUser
# 			 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 		 model.sixclicks_dev_orig.vwAttestationAttestors
# 			 source.sixclicks_dev_orig.assessment_models.AttestationAttestors
# -------------
# 		 model.sixclicks_dev_orig.vwAttestationItems
# 			 source.sixclicks_dev_orig.assessment_models.AttestationItems
# -------------
# 		 model.sixclicks_dev_orig.vwAttestationOwners
# 			 source.sixclicks_dev_orig.assessment_models.AttestationOwners
# -------------
# 		 model.sixclicks_dev_orig.vwAttestations
# 			 source.sixclicks_dev_orig.assessment_models.Attestations
# -------------
# 		 model.sixclicks_dev_orig.vwAttestorApprovals
# 			 source.sixclicks_dev_orig.assessment_models.AttestorApprovals
# -------------
# 	 exposure.sixclicks_dev_orig.Risks_Matrix_Details
# 		 model.sixclicks_dev_orig.vwAbpEntityChanges
# 			 source.sixclicks_dev_orig.assessment_models.AbpEntityChanges
# -------------
# 		 model.sixclicks_dev_orig.vwAbpTenants
# 			 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 		 model.sixclicks_dev_orig.vwAbpUser
# 			 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 		 model.sixclicks_dev_orig.vwAssessment
# 			 model.sixclicks_dev_orig.vwTenantVendor
# 				 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 		 model.sixclicks_dev_orig.vwAssessmentDomain
# 			 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 		 model.sixclicks_dev_orig.vwAssessmentRisk
# 			 source.sixclicks_dev_orig.assessment_models.AssessmentRisk
# -------------
# 		 model.sixclicks_dev_orig.vwAsset
# 			 source.sixclicks_dev_orig.assessment_models.Asset
# -------------
# 		 model.sixclicks_dev_orig.vwAuthorityProvision
# 			 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 		 model.sixclicks_dev_orig.vwControls
# 			 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 		 model.sixclicks_dev_orig.vwRegisterCustom
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 		 model.sixclicks_dev_orig.vwRegisterRecord
# 			 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 		 model.sixclicks_dev_orig.vwRisk
# 			 model.sixclicks_dev_orig.vwAbpTenants
# 				 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 			 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 		 model.sixclicks_dev_orig.vwRiskAssessment
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 		 model.sixclicks_dev_orig.vwRiskAssessmentAttributeList
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentTag
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentTag
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyDynamicFieldConfiguration
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyDynamicFieldConfiguration
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyDynamicFieldData
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyDynamicFieldData
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyDynamicFieldData
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyDynamicFieldData
# -------------
# 		 model.sixclicks_dev_orig.vwRiskAssessmentMatrix
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessment
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAssessmentTag
# 				 source.sixclicks_dev_orig.risk_models.RiskAssessmentTag
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyDynamicFieldConfiguration
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyDynamicFieldConfiguration
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyDynamicFieldData
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyDynamicFieldData
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyDynamicFieldData
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyDynamicFieldData
# -------------
# 		 model.sixclicks_dev_orig.vwRiskAsset
# 			 source.sixclicks_dev_orig.risk_models.RiskAsset
# -------------
# 		 model.sixclicks_dev_orig.vwRiskAttributeList
# 			 model.sixclicks_dev_orig.vwAssessment
# 				 model.sixclicks_dev_orig.vwTenantVendor
# 					 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 			 model.sixclicks_dev_orig.vwAssessment
# 				 model.sixclicks_dev_orig.vwTenantVendor
# 					 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 			 model.sixclicks_dev_orig.vwAssessmentDomain
# 				 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 			 model.sixclicks_dev_orig.vwAssessmentRisk
# 				 source.sixclicks_dev_orig.assessment_models.AssessmentRisk
# -------------
# 			 model.sixclicks_dev_orig.vwAssessmentRisk
# 				 source.sixclicks_dev_orig.assessment_models.AssessmentRisk
# -------------
# 			 model.sixclicks_dev_orig.vwAsset
# 				 source.sixclicks_dev_orig.assessment_models.Asset
# -------------
# 			 model.sixclicks_dev_orig.vwAuthority
# 				 source.sixclicks_dev_orig.assessment_models.Authority
# -------------
# 			 model.sixclicks_dev_orig.vwAuthorityProvision
# 				 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 			 model.sixclicks_dev_orig.vwControls
# 				 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 			 model.sixclicks_dev_orig.vwControls
# 				 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 			 model.sixclicks_dev_orig.vwPolicy
# 				 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 			 model.sixclicks_dev_orig.vwPolicy
# 				 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 			 model.sixclicks_dev_orig.vwPolicyDomain
# 				 source.sixclicks_dev_orig.assessment_models.PolicyDomain
# -------------
# 			 model.sixclicks_dev_orig.vwPolicyDomain
# 				 source.sixclicks_dev_orig.assessment_models.PolicyDomain
# -------------
# 			 model.sixclicks_dev_orig.vwQuestion
# 				 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRiskAsset
# 				 source.sixclicks_dev_orig.risk_models.RiskAsset
# -------------
# 			 model.sixclicks_dev_orig.vwRiskControl
# 				 source.sixclicks_dev_orig.risk_models.RiskControl
# -------------
# 			 model.sixclicks_dev_orig.vwRiskControl
# 				 source.sixclicks_dev_orig.risk_models.RiskControl
# -------------
# 			 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskOwner
# 				 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 					 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRiskProvision
# 				 source.sixclicks_dev_orig.risk_models.RiskProvision
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTag
# 				 source.sixclicks_dev_orig.risk_models.RiskTag
# -------------
# 			 model.sixclicks_dev_orig.vwRiskThirdParty
# 				 source.sixclicks_dev_orig.risk_models.RiskThirdParty
# -------------
# 			 model.sixclicks_dev_orig.vwRiskUser
# 				 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 					 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskUser
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTenantVendor
# 				 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwWorkflowStage
# 				 source.sixclicks_dev_orig.workflow_models.WorkflowStage
# -------------
# 			 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 		 model.sixclicks_dev_orig.vwRiskCategory
# 			 source.sixclicks_dev_orig.risk_models.RiskCategory
# -------------
# 		 model.sixclicks_dev_orig.vwRiskControl
# 			 source.sixclicks_dev_orig.risk_models.RiskControl
# -------------
# 		 model.sixclicks_dev_orig.vwRiskCustomDomain
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 				 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 		 model.sixclicks_dev_orig.vwRiskOwner
# 			 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 				 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 source.sixclicks_dev_orig.risk_models.RiskOwner
# -------------
# 		 model.sixclicks_dev_orig.vwRiskOwnerFilter
# 			 model.sixclicks_dev_orig.vwRiskOwner
# 				 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 					 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskOwner
# -------------
# 		 model.sixclicks_dev_orig.vwRiskProvision
# 			 source.sixclicks_dev_orig.risk_models.RiskProvision
# -------------
# 		 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 			 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 		 model.sixclicks_dev_orig.vwRiskReview
# 			 source.sixclicks_dev_orig.risk_models.RiskReview
# -------------
# 		 model.sixclicks_dev_orig.vwRiskTag
# 			 source.sixclicks_dev_orig.risk_models.RiskTag
# -------------
# 		 model.sixclicks_dev_orig.vwRiskTreatment
# 			 source.sixclicks_dev_orig.risk_models.RiskTreatment
# -------------
# 		 model.sixclicks_dev_orig.vwRiskTreatmentPlanAttributeList
# 			 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 				 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 model.sixclicks_dev_orig.vwAuthority
# 				 source.sixclicks_dev_orig.assessment_models.Authority
# -------------
# 			 model.sixclicks_dev_orig.vwAuthorityProvision
# 				 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 			 model.sixclicks_dev_orig.vwControls
# 				 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 			 model.sixclicks_dev_orig.vwControls
# 				 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 			 model.sixclicks_dev_orig.vwPolicy
# 				 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 			 model.sixclicks_dev_orig.vwPolicy
# 				 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 			 model.sixclicks_dev_orig.vwPolicyDomain
# 				 source.sixclicks_dev_orig.assessment_models.PolicyDomain
# -------------
# 			 model.sixclicks_dev_orig.vwPolicyDomain
# 				 source.sixclicks_dev_orig.assessment_models.PolicyDomain
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTag
# 				 source.sixclicks_dev_orig.risk_models.RiskTag
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatment
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatment
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlan
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlan
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanAssociation
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanAssociation
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanComment
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanComment
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanControl
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanControl
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanControl
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanControl
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanOwner
# 				 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 					 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanProvision
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanProvision
# -------------
# 			 model.sixclicks_dev_orig.vwStatusLists
# 				 source.sixclicks_dev_orig.statuslists_models.StatusLists
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 		 model.sixclicks_dev_orig.vwRiskTreatmentPlanOwnerFilter
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanOwner
# 				 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 					 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanOwner
# -------------
# 		 model.sixclicks_dev_orig.vwRisksCustomData
# 			 model.sixclicks_dev_orig.vwRiskCustomDataFreeText
# 				 model.sixclicks_dev_orig.vwRiskCustomAttributeData
# 					 source.sixclicks_dev_orig.risk_models.RiskCustomAttributeData
# -------------
# 				 model.sixclicks_dev_orig.vwRiskThirdPartyControlCustomText
# 					 source.sixclicks_dev_orig.risk_models.RiskThirdPartyControlCustomText
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 		 model.sixclicks_dev_orig.vwStatusLists
# 			 source.sixclicks_dev_orig.statuslists_models.StatusLists
# -------------
# 		 model.sixclicks_dev_orig.vwTags
# 			 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 		 model.sixclicks_dev_orig.vwTenantVendor
# 			 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 		 model.sixclicks_dev_orig.vwWorkflowStage
# 			 source.sixclicks_dev_orig.workflow_models.WorkflowStage
# -------------
# 	 exposure.sixclicks_dev_orig.Question_Based_Assessment_Question_Assigned_User_Details
# 		 model.sixclicks_dev_orig.vwAbpTenants
# 			 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 		 model.sixclicks_dev_orig.vwAbpUser
# 			 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 		 model.sixclicks_dev_orig.vwAnswer
# 			 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 		 model.sixclicks_dev_orig.vwAssessment
# 			 model.sixclicks_dev_orig.vwTenantVendor
# 				 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 		 model.sixclicks_dev_orig.vwAssessmentDomain
# 			 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 		 model.sixclicks_dev_orig.vwAssessmentTag
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.AssessmentTag
# -------------
# 		 model.sixclicks_dev_orig.vwQuestion
# 			 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionAnswer
# 			 model.sixclicks_dev_orig.vwAnswer
# 				 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 model.sixclicks_dev_orig.vwAnswerChooseMany
# 				 model.sixclicks_dev_orig.vwAnswerResponseChooseMany
# 					 model.sixclicks_dev_orig.vwQuestionAll
# 						 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAll
# 				 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionAssignment
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 model.sixclicks_dev_orig.vwAssessment
# 				 model.sixclicks_dev_orig.vwTenantVendor
# 					 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 			 model.sixclicks_dev_orig.vwAssessment
# 				 model.sixclicks_dev_orig.vwTenantVendor
# 					 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 			 model.sixclicks_dev_orig.vwAssessmentDomain
# 				 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 			 model.sixclicks_dev_orig.vwAssessmentDomain
# 				 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 			 model.sixclicks_dev_orig.vwAssessmentDomain
# 				 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAnswer
# 				 model.sixclicks_dev_orig.vwAnswer
# 					 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 model.sixclicks_dev_orig.vwAnswerChooseMany
# 					 model.sixclicks_dev_orig.vwAnswerResponseChooseMany
# 						 model.sixclicks_dev_orig.vwQuestionAll
# 							 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 model.sixclicks_dev_orig.vwQuestionAll
# 					 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAnswer
# 				 model.sixclicks_dev_orig.vwAnswer
# 					 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 model.sixclicks_dev_orig.vwAnswerChooseMany
# 					 model.sixclicks_dev_orig.vwAnswerResponseChooseMany
# 						 model.sixclicks_dev_orig.vwQuestionAll
# 							 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 model.sixclicks_dev_orig.vwQuestionAll
# 					 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAnswer
# 				 model.sixclicks_dev_orig.vwAnswer
# 					 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 model.sixclicks_dev_orig.vwAnswerChooseMany
# 					 model.sixclicks_dev_orig.vwAnswerResponseChooseMany
# 						 model.sixclicks_dev_orig.vwQuestionAll
# 							 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 model.sixclicks_dev_orig.vwQuestionAll
# 					 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionVendorUser
# 				 source.sixclicks_dev_orig.assessment_models.QuestionVendorUser
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionVendorUser
# 				 source.sixclicks_dev_orig.assessment_models.QuestionVendorUser
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.QuestionVendorUser
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionGroupAnswers
# 			 model.sixclicks_dev_orig.vwAnswer
# 				 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAll
# 				 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionGroup
# 				 source.sixclicks_dev_orig.assessment_models.QuestionGroup
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionGroupResponse
# 				 source.sixclicks_dev_orig.assessment_models.QuestionGroupResponse
# -------------
# 		 model.sixclicks_dev_orig.vwRpt_TenantVendorGroup
# 			 source.sixclicks_dev_orig.tenant_models.Rpt_TenantVendorGroup
# -------------
# 		 model.sixclicks_dev_orig.vwRpt_VendorGroup
# 			 source.sixclicks_dev_orig.tenant_models.Rpt_VendorGroup
# -------------
# 		 model.sixclicks_dev_orig.vwTags
# 			 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 		 model.sixclicks_dev_orig.vwTenantVendor
# 			 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 	 exposure.sixclicks_dev_orig.Authority_Summary_View
# 		 model.sixclicks_dev_orig.vwAuthority
# 			 source.sixclicks_dev_orig.assessment_models.Authority
# -------------
# 		 model.sixclicks_dev_orig.vwAuthorityProvision
# 			 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 		 model.sixclicks_dev_orig.vwAuthorityProvisionCustomTable
# 			 model.sixclicks_dev_orig.vwAuthority
# 				 source.sixclicks_dev_orig.assessment_models.Authority
# -------------
# 			 model.sixclicks_dev_orig.vwAuthorityProvision
# 				 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 			 model.sixclicks_dev_orig.vwAuthorityProvision
# 				 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 			 model.sixclicks_dev_orig.vwAuthorityProvisionCustomField
# 				 source.sixclicks_dev_orig.assessment_models.AuthorityProvisionCustomField
# -------------
# 		 model.sixclicks_dev_orig.vwAuthorityTenantRelationship
# 			 model.sixclicks_dev_orig.vwDirectAuthority
# 				 source.sixclicks_dev_orig.assessment_models.Authority
# -------------
# 				 source.sixclicks_dev_orig.tenant_models.TenantAuthority
# -------------
# 	 exposure.sixclicks_dev_orig.Task_Detail_View
# 		 model.sixclicks_dev_orig.vwTaskDetail
# 			 model.sixclicks_dev_orig.vwAbpDateLog
# 				 source.sixclicks_dev_orig.assessment_models.AbpEntityChangeSets
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpEntityChanges
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpEntityPropertyChanges
# -------------
# 			 model.sixclicks_dev_orig.vwAbpUser
# 				 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 			 model.sixclicks_dev_orig.vwIssueAction
# 				 source.sixclicks_dev_orig.issue_models.IssueAction
# -------------
# 			 model.sixclicks_dev_orig.vwResponsibilityDetail
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 model.sixclicks_dev_orig.vwStatement
# 					 source.sixclicks_dev_orig.statement_models.Statement
# -------------
# 				 model.sixclicks_dev_orig.vwStatement
# 					 source.sixclicks_dev_orig.statement_models.Statement
# -------------
# 				 model.sixclicks_dev_orig.vwStatementResponse
# 					 source.sixclicks_dev_orig.statement_models.StatementResponse
# -------------
# 				 model.sixclicks_dev_orig.vwStatementResponse
# 					 source.sixclicks_dev_orig.statement_models.StatementResponse
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlan
# 				 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlan
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanAttributeList
# 				 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 					 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 model.sixclicks_dev_orig.vwAbpUser
# 					 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 				 model.sixclicks_dev_orig.vwAuthority
# 					 source.sixclicks_dev_orig.assessment_models.Authority
# -------------
# 				 model.sixclicks_dev_orig.vwAuthorityProvision
# 					 source.sixclicks_dev_orig.assessment_models.AuthorityProvision
# -------------
# 				 model.sixclicks_dev_orig.vwControls
# 					 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 				 model.sixclicks_dev_orig.vwControls
# 					 source.sixclicks_dev_orig.assessment_models.Controls
# -------------
# 				 model.sixclicks_dev_orig.vwPolicy
# 					 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 				 model.sixclicks_dev_orig.vwPolicy
# 					 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 				 model.sixclicks_dev_orig.vwPolicyDomain
# 					 source.sixclicks_dev_orig.assessment_models.PolicyDomain
# -------------
# 				 model.sixclicks_dev_orig.vwPolicyDomain
# 					 source.sixclicks_dev_orig.assessment_models.PolicyDomain
# -------------
# 				 model.sixclicks_dev_orig.vwRisk
# 					 model.sixclicks_dev_orig.vwAbpTenants
# 						 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 						 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTag
# 					 source.sixclicks_dev_orig.risk_models.RiskTag
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatment
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatment
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatment
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatment
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlan
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlan
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanAssociation
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanAssociation
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanComment
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanComment
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanControl
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanControl
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanControl
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanControl
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanOwner
# 					 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 						 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 					 model.sixclicks_dev_orig.vwAbpUser
# 						 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanProvision
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanProvision
# -------------
# 				 model.sixclicks_dev_orig.vwStatusLists
# 					 source.sixclicks_dev_orig.statuslists_models.StatusLists
# -------------
# 				 model.sixclicks_dev_orig.vwTags
# 					 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwRiskTreatmentPlanOwnerFilter
# 				 model.sixclicks_dev_orig.vwRiskTreatmentPlanOwner
# 					 model.sixclicks_dev_orig.vwAbpOrganizationUnits
# 						 source.sixclicks_dev_orig.assessment_models.AbpOrganizationUnits
# -------------
# 					 model.sixclicks_dev_orig.vwAbpUser
# 						 source.sixclicks_dev_orig.assessment_models.AbpUsers
# -------------
# 					 source.sixclicks_dev_orig.risk_models.RiskTreatmentPlanOwner
# -------------
# 	 exposure.sixclicks_dev_orig.Question_Based_Assessment_Answer_Details_Risk_Radar
# 		 model.sixclicks_dev_orig.vwAnswerResponseFilter
# 			 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 		 model.sixclicks_dev_orig.vwAssessment
# 			 model.sixclicks_dev_orig.vwTenantVendor
# 				 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 		 model.sixclicks_dev_orig.vwAssessmentDomain
# 			 source.sixclicks_dev_orig.assessment_models.AssessmentDomain
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionAnswer
# 			 model.sixclicks_dev_orig.vwAnswer
# 				 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 model.sixclicks_dev_orig.vwAnswerChooseMany
# 				 model.sixclicks_dev_orig.vwAnswerResponseChooseMany
# 					 model.sixclicks_dev_orig.vwQuestionAll
# 						 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAll
# 				 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionGroupAnswers
# 			 model.sixclicks_dev_orig.vwAnswer
# 				 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionAll
# 				 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionGroup
# 				 source.sixclicks_dev_orig.assessment_models.QuestionGroup
# -------------
# 			 model.sixclicks_dev_orig.vwQuestionGroupResponse
# 				 source.sixclicks_dev_orig.assessment_models.QuestionGroupResponse
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionTagsJoined
# 			 model.sixclicks_dev_orig.vwQuestionTags
# 				 source.sixclicks_dev_orig.assessment_models.QuestionTags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 		 model.sixclicks_dev_orig.vwQuestionTargetResponse
# 			 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 		 model.sixclicks_dev_orig.vwTenantVendor
# 			 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 		 model.sixclicks_dev_orig.vwThirdPartyCustomTable
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyData
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyData
# -------------
# 	 exposure.sixclicks_dev_orig.Authority_to_Assessment_Self-Service_View
# 		 model.sixclicks_dev_orig.vwAnswerResponse_lambda
# 			 model.sixclicks_dev_orig.vwAnswerResponse_source
# 				 source.sixclicks_dev_orig.assessment_models.Answer
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.Question
# -------------
# 		 model.sixclicks_dev_orig.vwAssessmentAuthority_source
# 			 model.sixclicks_dev_orig.vwAssessment
# 				 model.sixclicks_dev_orig.vwTenantVendor
# 					 source.sixclicks_dev_orig.tenant_models.TenantVendor
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# 			 model.sixclicks_dev_orig.vwAuthorityPolicy
# 				 source.sixclicks_dev_orig.assessment_models.AuthorityPolicy
# -------------
# 			 model.sixclicks_dev_orig.vwPolicy
# 				 source.sixclicks_dev_orig.assessment_models.Policy
# -------------
# 			 source.sixclicks_dev_orig.assessment_models.Assessment
# -------------
# ...
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordCustomAttributesData
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordCustomAttributesData
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordCustomAttributesData
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordCustomAttributesData
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordOwnerList
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordOwner
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordOwner
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwThirdPartyControl
# 				 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 		 model.sixclicks_dev_orig.vwCustomRegisterAttributesList
# 			 model.sixclicks_dev_orig.vwIssueRegisterRecord
# 				 source.sixclicks_dev_orig.issue_models.IssueRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwIssues
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.issue_models.IssueAction
# -------------
# 				 source.sixclicks_dev_orig.issue_models.Issues
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegister
# 				 source.sixclicks_dev_orig.register_models.Register
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecord
# 				 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordFreeTextData
# 				 model.sixclicks_dev_orig.vwRegisterRecord
# 					 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecord
# 					 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecord
# 					 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecord
# 					 source.sixclicks_dev_orig.register_models.RegisterRecord
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordCustomAttributesData
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordCustomAttributesData
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 				 model.sixclicks_dev_orig.vwRegisterRecordThirdPartyControlFreeText
# 					 source.sixclicks_dev_orig.register_models.RegisterRecordThirdPartyControlFreeText
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyAttributes
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyAttributes
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 				 model.sixclicks_dev_orig.vwThirdPartyControl
# 					 source.sixclicks_dev_orig.issue_models.ThirdPartyControl
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterRecordTag
# 				 source.sixclicks_dev_orig.register_models.RegisterRecordTag
# -------------
# 			 model.sixclicks_dev_orig.vwRisk
# 				 model.sixclicks_dev_orig.vwAbpTenants
# 					 source.sixclicks_dev_orig.assessment_models.AbpEditions
# -------------
# 					 source.sixclicks_dev_orig.assessment_models.AbpTenants
# -------------
# 				 source.sixclicks_dev_orig.risk_models.Risk
# -------------
# 			 model.sixclicks_dev_orig.vwRiskRegisterRecord
# 				 source.sixclicks_dev_orig.risk_models.RiskRegisterRecord
# -------------
# 			 model.sixclicks_dev_orig.vwTags
# 				 source.sixclicks_dev_orig.assessment_models.Tags
# -------------
# 		 model.sixclicks_dev_orig.vwRegisterAccessMemberList
# 			 model.sixclicks_dev_orig.vwRegisterAccessMember
# 				 source.sixclicks_dev_orig.register_models.RegisterAccessMember
# -------------
# 			 model.sixclicks_dev_orig.vwRegisterAccessMember
# 				 source.sixclicks_dev_orig.register_models.RegisterAccessMember
# -------------

# %% [markdown]
# Orphaned objects
# 1. pass_count = 0
# 2. Is not a base_view - we do not delete any base views
# 3. Ignore Archived for Deletion folder

# %%
orphaned_views = list(set(tree_df.query("pass_count == 0 & parent_group != 'base_view'")["parent"].tolist() ))

# %% [markdown]
# form the shell command

# %%
# Construct the columns to make the shell script
move_df = obj_df[obj_df["id"].isin(orphaned_views)][["id","name","original_file_path"]]
move_df["move_to"] = "models/Archive_for_deletion"
# Ignore unreferenced files in Archive folder already
move_df = move_df.query('~original_file_path.str.contains("Archive_for_deletion")')
move_df
# Out:
#                                                     id  \
# 11   model.sixclicks_dev_orig.ProvisionCustomFieldV...
# 12       model.sixclicks_dev_orig.AnswerResponse_batch
# 13       model.sixclicks_dev_orig.QuestionOption_batch
# 14   model.sixclicks_dev_orig.vwAnswerResponseChoos...
# 15   model.sixclicks_dev_orig.AnswerResponseChooseM...
# 16   model.sixclicks_dev_orig.vwAnswerResponseChoos...
# 88   model.sixclicks_dev_orig.vwControlSetToAuthori...
# 89   model.sixclicks_dev_orig.vwControlSetToAuthori...
# 104               model.sixclicks_dev_orig.vwUsageView
# 283           model.sixclicks_dev_orig.vwRiskAuthority
# 287            model.sixclicks_dev_orig.vwRiskAuditLog
# 289  model.sixclicks_dev_orig.vwRiskProvision_Provi...
# 291  model.sixclicks_dev_orig.vwFindexRiskAssessmen...
# 292    model.sixclicks_dev_orig.vwRiskControl_Controls
# 325                model.sixclicks_dev_orig.DimControl
# 326  model.sixclicks_dev_orig.FactRelationProvision...
# 327              model.sixclicks_dev_orig.DimProvision
# 328              model.sixclicks_dev_orig.DimAuthority
# 338  model.sixclicks_dev_orig.vwAuthorityToControlS...
# 340  model.sixclicks_dev_orig.vwAuthorityToControlS...
# 389  model.sixclicks_dev_orig.yfTargetAuthorityToRB...
# 416         model.sixclicks_dev_orig.vwControlSetLabel
# 418  model.sixclicks_dev_orig.vwResponsibilityOwner...
# 419  model.sixclicks_dev_orig.vwControlSetStakeholders
# 422  model.sixclicks_dev_orig.vwResponsibilityTask(...
# 567  model.sixclicks_dev_orig.AuthorityToAssessment...
# 571  model.sixclicks_dev_orig.AuthorityAssessmentQu...
# 572             model.sixclicks_dev_orig.DimControlSet
# 573  model.sixclicks_dev_orig.FactRelationAuthority...
#
#                                         name  \
# 11           ProvisionCustomFieldValue_batch
# 12                      AnswerResponse_batch
# 13                      QuestionOption_batch
# 14         vwAnswerResponseChooseMany_lambda
# 15            AnswerResponseChooseMany_batch
# 16         vwAnswerResponseChooseMany_source
# 88          vwControlSetToAuthority_Overview
# 89             vwControlSetToAuthority_Table
# 104                              vwUsageView
# 283                          vwRiskAuthority
# 287                           vwRiskAuditLog
# 289                vwRiskProvision_Provision
# 291            vwFindexRiskAssessmentDetails
# 292                   vwRiskControl_Controls
# 325                               DimControl
# 326           FactRelationProvisionToControl
# 327                             DimProvision
# 328                             DimAuthority
# 338            vwAuthorityToControlSet_Table
# 340         vwAuthorityToControlSet_Overview
# 389            yfTargetAuthorityToRBA_filter
# 416                        vwControlSetLabel
# 418            vwResponsibilityOwnersMembers
# 419                 vwControlSetStakeholders
# 422         vwResponsibilityTask(deprecated)
# 567        AuthorityToAssessmentFilter_batch
# 571  AuthorityAssessmentQuestionAnswer_batch
# 572                            DimControlSet
# 573        FactRelationAuthorityToControlSet
#
#                                     original_file_path  \
# 11   models/Incremental_tables/AuthorityToAssessmen...
# 12   models/Incremental_tables/AuthorityToAssessmen...
# 13   models/Incremental_tables/QuestionAnswer/Quest...
# 14   models/Incremental_tables/AnswerResponseChoose...
# 15   models/Incremental_tables/AnswerResponseChoose...
# 16   models/Incremental_tables/AnswerResponseChoose...
# 88   models/Assessment_models/base/Controls/Transfo...
# 89   models/Assessment_models/base/Controls/Transfo...
# 104  models/Assessment_models/base/Abp/Transformati...
# 283  models/Risk_models/transformed/vwRiskAuthority...
# 287  models/Risk_models/transformed/vwRiskAuditLog.sql
# 289  models/Risk_models/transformed/vwRiskProvision...
# 291  models/Risk_models/transformed/vwFindexRiskAss...
# 292  models/Risk_models/transformed/vwRiskControl_C...
# 325                    models/warehouse/DimControl.sql
# 326  models/warehouse/FactRelationProvisionToContro...
# 327                  models/warehouse/DimProvision.sql
# 328                  models/warehouse/DimAuthority.sql
# 338  models/Authority_models/Authority/Transformed/...
# 340  models/Authority_models/Authority/Transformed/...
# 389  models/YellowfinReport_views/ControlSetAuthori...
# 416  models/Assessment_models/base/Policy/Transform...
# 418  models/Statement_models/Transformed/vwResponsi...
# 419  models/Assessment_models/base/Policy/Transform...
# 422  models/Responsibility_models/Base/vwResponsibi...
# 567  models/Incremental_tables/AuthorityToAssessmen...
# 571  models/Incremental_tables/AuthorityToAssessmen...
# 572  models/Assessment_models/base/Policy/Transform...
# 573  models/Assessment_models/base/Policy/Transform...
#
#                          move_to
# 11   models/Archive_for_deletion
# 12   models/Archive_for_deletion
# 13   models/Archive_for_deletion
# 14   models/Archive_for_deletion
# 15   models/Archive_for_deletion
# 16   models/Archive_for_deletion
# 88   models/Archive_for_deletion
# 89   models/Archive_for_deletion
# 104  models/Archive_for_deletion
# 283  models/Archive_for_deletion
# 287  models/Archive_for_deletion
# 289  models/Archive_for_deletion
# 291  models/Archive_for_deletion
# 292  models/Archive_for_deletion
# 325  models/Archive_for_deletion
# 326  models/Archive_for_deletion
# 327  models/Archive_for_deletion
# 328  models/Archive_for_deletion
# 338  models/Archive_for_deletion
# 340  models/Archive_for_deletion
# 389  models/Archive_for_deletion
# 416  models/Archive_for_deletion
# 418  models/Archive_for_deletion
# 419  models/Archive_for_deletion
# 422  models/Archive_for_deletion
# 567  models/Archive_for_deletion
# 571  models/Archive_for_deletion
# 572  models/Archive_for_deletion
# 573  models/Archive_for_deletion

# %%
# Sheel script string
move_df["shell"] = "mv " + move_df["original_file_path"] + " " + move_df["move_to"]
move_df["shell"]
# Out:
# 11     mv models/Incremental_tables/AuthorityToAssess...
# 12     mv models/Incremental_tables/AuthorityToAssess...
# 13     mv models/Incremental_tables/QuestionAnswer/Qu...
# 14     mv models/Incremental_tables/AnswerResponseCho...
# 15     mv models/Incremental_tables/AnswerResponseCho...
# 16     mv models/Incremental_tables/AnswerResponseCho...
# 88     mv models/Assessment_models/base/Controls/Tran...
# 89     mv models/Assessment_models/base/Controls/Tran...
# 104    mv models/Assessment_models/base/Abp/Transform...
# 283    mv models/Risk_models/transformed/vwRiskAuthor...
# 287    mv models/Risk_models/transformed/vwRiskAuditL...
# 289    mv models/Risk_models/transformed/vwRiskProvis...
# 291    mv models/Risk_models/transformed/vwFindexRisk...
# 292    mv models/Risk_models/transformed/vwRiskContro...
# 325    mv models/warehouse/DimControl.sql models/Arch...
# 326    mv models/warehouse/FactRelationProvisionToCon...
# 327    mv models/warehouse/DimProvision.sql models/Ar...
# 328    mv models/warehouse/DimAuthority.sql models/Ar...
# 338    mv models/Authority_models/Authority/Transform...
# 340    mv models/Authority_models/Authority/Transform...
# 389    mv models/YellowfinReport_views/ControlSetAuth...
# 416    mv models/Assessment_models/base/Policy/Transf...
# 418    mv models/Statement_models/Transformed/vwRespo...
# 419    mv models/Assessment_models/base/Policy/Transf...
# 422    mv models/Responsibility_models/Base/vwRespons...
# 567    mv models/Incremental_tables/AuthorityToAssess...
# 571    mv models/Incremental_tables/AuthorityToAssess...
# 572    mv models/Assessment_models/base/Policy/Transf...
# 573    mv models/Assessment_models/base/Policy/Transf...
# Name: shell, dtype: object

# %% [markdown]
# Create shell script

# %%
os.getcwd()
# Out:
# '/home/herman/projects/6clicksReporting/target'

# %%
move_df["shell"].to_csv("archive_orphans.sh", index=False, header=False)

# %% [markdown]
# Change directory to projects root folder and run the script

# %%
#os.chdir("..")
#!chmod +x target/archive_orphans.sh
#!bash target/archive_orphans.sh
